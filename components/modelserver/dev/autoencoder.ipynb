# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path

# %%
data_path = '../data/testset.csv'
df = pd.read_csv(data_path)
df = df.iloc[3:, 6]
df = pd.to_numeric(df)
index = 0
output = []
while index in range(0, len(df.index)):
    temp=df.iloc[index:index+512]
    if len(temp)==512:
        output.append(temp.to_list())
    index = index+10

train = torch.tensor(output, dtype=torch.float32)
data_loader = torch.utils.data.DataLoader(dataset=train, batch_size=16, shuffle=True)

# %%
class Autoencoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(512, 128), 
            nn.ReLU(),
            nn.Linear(128, 32),
            nn.ReLU(),
            nn.Linear(32, 8),
        )

        self.decoder = nn.Sequential(
            nn.Linear(8, 32),
            nn.ReLU(),
            nn.Linear(32, 128),
            nn.ReLU(),
            nn.Linear(128, 512)
        )


    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
model = Autoencoder()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=0)

# %%
num_epochs = 200
outputs = []
for epoch in range(num_epochs):
    for input in data_loader:
        recon = model(input)
        loss = criterion(recon, input)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    print(f'Epoch:{epoch+1}, Loss:{loss.item(): .4f}')
    outputs.append((epoch, input, recon))
# Out:
# Epoch:1, Loss: 0.5568
# Epoch:2, Loss: 0.5053
# Epoch:3, Loss: 0.3794
# Epoch:4, Loss: 0.2027
# Epoch:5, Loss: 0.0354
# Epoch:6, Loss: 0.0185
# Epoch:7, Loss: 0.0156
# Epoch:8, Loss: 0.0156
# Epoch:9, Loss: 0.0152
# Epoch:10, Loss: 0.0152
# Epoch:11, Loss: 0.0150
# Epoch:12, Loss: 0.0152
# Epoch:13, Loss: 0.0150
# Epoch:14, Loss: 0.0149
# Epoch:15, Loss: 0.0149
# Epoch:16, Loss: 0.0149
# Epoch:17, Loss: 0.0143
# Epoch:18, Loss: 0.0150
# Epoch:19, Loss: 0.0145
# Epoch:20, Loss: 0.0149
# Epoch:21, Loss: 0.0147
# Epoch:22, Loss: 0.0146
# Epoch:23, Loss: 0.0150
# Epoch:24, Loss: 0.0150
# Epoch:25, Loss: 0.0152
# Epoch:26, Loss: 0.0150
# Epoch:27, Loss: 0.0148
# Epoch:28, Loss: 0.0147
# Epoch:29, Loss: 0.0152
# Epoch:30, Loss: 0.0158
# Epoch:31, Loss: 0.0152
# Epoch:32, Loss: 0.0150
# Epoch:33, Loss: 0.0146
# Epoch:34, Loss: 0.0151
# Epoch:35, Loss: 0.0146
# Epoch:36, Loss: 0.0148
# Epoch:37, Loss: 0.0153
# Epoch:38, Loss: 0.0149
# Epoch:39, Loss: 0.0143
# Epoch:40, Loss: 0.0147
# Epoch:41, Loss: 0.0147
# Epoch:42, Loss: 0.0149
# Epoch:43, Loss: 0.0147
# Epoch:44, Loss: 0.0147
# Epoch:45, Loss: 0.0145
# Epoch:46, Loss: 0.0147
# Epoch:47, Loss: 0.0145
# Epoch:48, Loss: 0.0146
# Epoch:49, Loss: 0.0150
# Epoch:50, Loss: 0.0149
# Epoch:51, Loss: 0.0150
# Epoch:52, Loss: 0.0151
# Epoch:53, Loss: 0.0150
# Epoch:54, Loss: 0.0154
# Epoch:55, Loss: 0.0149
# Epoch:56, Loss: 0.0155
# Epoch:57, Loss: 0.0147
# Epoch:58, Loss: 0.0151
# Epoch:59, Loss: 0.0150
# Epoch:60, Loss: 0.0143
# Epoch:61, Loss: 0.0149
# Epoch:62, Loss: 0.0146
# Epoch:63, Loss: 0.0147
# Epoch:64, Loss: 0.0152
# Epoch:65, Loss: 0.0153
# Epoch:66, Loss: 0.0146
# Epoch:67, Loss: 0.0159
# Epoch:68, Loss: 0.0148
# Epoch:69, Loss: 0.0149
# Epoch:70, Loss: 0.0151
# Epoch:71, Loss: 0.0148
# Epoch:72, Loss: 0.0154
# Epoch:73, Loss: 0.0149
# Epoch:74, Loss: 0.0147
# Epoch:75, Loss: 0.0148
# Epoch:76, Loss: 0.0144
# Epoch:77, Loss: 0.0146
# Epoch:78, Loss: 0.0147
# Epoch:79, Loss: 0.0146
# Epoch:80, Loss: 0.0157
# Epoch:81, Loss: 0.0146
# Epoch:82, Loss: 0.0143
# Epoch:83, Loss: 0.0151
# Epoch:84, Loss: 0.0149
# Epoch:85, Loss: 0.0149
# Epoch:86, Loss: 0.0150
# Epoch:87, Loss: 0.0147
# Epoch:88, Loss: 0.0153
# Epoch:89, Loss: 0.0149
# Epoch:90, Loss: 0.0157
# Epoch:91, Loss: 0.0150
# Epoch:92, Loss: 0.0149
# Epoch:93, Loss: 0.0154
# Epoch:94, Loss: 0.0143
# Epoch:95, Loss: 0.0149
# Epoch:96, Loss: 0.0146
# Epoch:97, Loss: 0.0144
# Epoch:98, Loss: 0.0150
# Epoch:99, Loss: 0.0146
# Epoch:100, Loss: 0.0148
# Epoch:101, Loss: 0.0146
# Epoch:102, Loss: 0.0147
# Epoch:103, Loss: 0.0144
# Epoch:104, Loss: 0.0147
# Epoch:105, Loss: 0.0147
# Epoch:106, Loss: 0.0151
# Epoch:107, Loss: 0.0146
# Epoch:108, Loss: 0.0148
# Epoch:109, Loss: 0.0149
# Epoch:110, Loss: 0.0145
# Epoch:111, Loss: 0.0146
# Epoch:112, Loss: 0.0144
# Epoch:113, Loss: 0.0141
# Epoch:114, Loss: 0.0149
# Epoch:115, Loss: 0.0148
# Epoch:116, Loss: 0.0143
# Epoch:117, Loss: 0.0146
# Epoch:118, Loss: 0.0147
# Epoch:119, Loss: 0.0146
# Epoch:120, Loss: 0.0146
# Epoch:121, Loss: 0.0146
# Epoch:122, Loss: 0.0148
# Epoch:123, Loss: 0.0147
# Epoch:124, Loss: 0.0150
# Epoch:125, Loss: 0.0143
# Epoch:126, Loss: 0.0147
# Epoch:127, Loss: 0.0150
# Epoch:128, Loss: 0.0145
# Epoch:129, Loss: 0.0147
# Epoch:130, Loss: 0.0146
# Epoch:131, Loss: 0.0145
# Epoch:132, Loss: 0.0149
# Epoch:133, Loss: 0.0153
# Epoch:134, Loss: 0.0155
# Epoch:135, Loss: 0.0157
# Epoch:136, Loss: 0.0152
# Epoch:137, Loss: 0.0156
# Epoch:138, Loss: 0.0144
# Epoch:139, Loss: 0.0154
# Epoch:140, Loss: 0.0149
# Epoch:141, Loss: 0.0149
# Epoch:142, Loss: 0.0146
# Epoch:143, Loss: 0.0146
# Epoch:144, Loss: 0.0148
# Epoch:145, Loss: 0.0145
# Epoch:146, Loss: 0.0150
# Epoch:147, Loss: 0.0144
# Epoch:148, Loss: 0.0145
# Epoch:149, Loss: 0.0146
# Epoch:150, Loss: 0.0146
# Epoch:151, Loss: 0.0145
# Epoch:152, Loss: 0.0150
# Epoch:153, Loss: 0.0143
# Epoch:154, Loss: 0.0149
# Epoch:155, Loss: 0.0143
# Epoch:156, Loss: 0.0150
# Epoch:157, Loss: 0.0146
# Epoch:158, Loss: 0.0146
# Epoch:159, Loss: 0.0145
# Epoch:160, Loss: 0.0146
# Epoch:161, Loss: 0.0143
# Epoch:162, Loss: 0.0147
# Epoch:163, Loss: 0.0148
# Epoch:164, Loss: 0.0145
# Epoch:165, Loss: 0.0146
# Epoch:166, Loss: 0.0145
# Epoch:167, Loss: 0.0147
# Epoch:168, Loss: 0.0146
# Epoch:169, Loss: 0.0146
# Epoch:170, Loss: 0.0142
# Epoch:171, Loss: 0.0145
# Epoch:172, Loss: 0.0144
# Epoch:173, Loss: 0.0149
# Epoch:174, Loss: 0.0146
# Epoch:175, Loss: 0.0145
# Epoch:176, Loss: 0.0146
# Epoch:177, Loss: 0.0146
# Epoch:178, Loss: 0.0151
# Epoch:179, Loss: 0.0147
# Epoch:180, Loss: 0.0150
# Epoch:181, Loss: 0.0144
# Epoch:182, Loss: 0.0147
# Epoch:183, Loss: 0.0146
# Epoch:184, Loss: 0.0144
# Epoch:185, Loss: 0.0144
# Epoch:186, Loss: 0.0145
# Epoch:187, Loss: 0.0150
# Epoch:188, Loss: 0.0142
# Epoch:189, Loss: 0.0149
# Epoch:190, Loss: 0.0148
# Epoch:191, Loss: 0.0149
# Epoch:192, Loss: 0.0147
# Epoch:193, Loss: 0.0146
# Epoch:194, Loss: 0.0148
# Epoch:195, Loss: 0.0142
# Epoch:196, Loss: 0.0147
# Epoch:197, Loss: 0.0147
# Epoch:198, Loss: 0.0149
# Epoch:199, Loss: 0.0147
# Epoch:200, Loss: 0.0143

# %%
model.eval()

inf = model(train).detach()

l = []

for i, item in enumerate(train):
    l.append(criterion(item, inf[i]).item())

mn = np.mean(l)
std = np.std(l)
count = 0
for i, item in enumerate(l):
    if item > mn + 3*std and count < 10:
        count= count+1
        plt.figure()
        plt.plot(train[i])
        plt.plot(inf[i])

# %%
for k in range (0, num_epochs, 100):
    plt.figure(figsize=(15, 4))
    plt.gray()
    input = outputs[k][1].detach().numpy()
    recon = outputs[k][2].detach().numpy()
    for i, item in enumerate(input):
        if i >= 1: break
        plt.subplot(2, 1, 1)
        plt.plot(item)
    
    for i, item in enumerate(recon):
        if i >= 1: break
        # plt.subplot(2, 1, 2)
        plt.plot(item)
